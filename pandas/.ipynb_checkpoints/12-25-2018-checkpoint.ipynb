# %%
# %load_ext autotime

# %%
import pandas as pd
# Out:
# time: 753 ms

# %% [markdown]
# # Importing CSV File

# %%
df = pd.read_csv("loan_test.csv")
# Out:
# time: 11.4 s

# %%
df
# Out:
#         Unnamed: 0  loan_amount  funded_amount  investor_funds        term  \
# 0                0         5000           5000      4975.00000   36 months
# 1                1         2500           2500      2500.00000   60 months
# 2                2         2400           2400      2400.00000   36 months
# 3                3        10000          10000     10000.00000   36 months
# 4                4         3000           3000      3000.00000   60 months
# 5                5         5000           5000      5000.00000   36 months
# 6                6         7000           7000      7000.00000   60 months
# 7                7         3000           3000      3000.00000   36 months
# 8                8         5600           5600      5600.00000   60 months
# 9                9         5375           5375      5350.00000   60 months
# 10              10         6500           6500      6500.00000   60 months
# 11              11        12000          12000     12000.00000   36 months
# 12              12         9000           9000      9000.00000   36 months
# 13              13         3000           3000      3000.00000   36 months
# 14              14        10000          10000     10000.00000   36 months
# 15              15         1000           1000      1000.00000   36 months
# 16              16        10000          10000     10000.00000   36 months
# 17              17         3600           3600      3600.00000   36 months
# 18              18         6000           6000      6000.00000   36 months
# 19              19         9200           9200      9200.00000   36 months
# 20              20        20250          20250     19142.16108   60 months
# 21              21        21000          21000     21000.00000   36 months
# 22              22        10000          10000     10000.00000   36 months
# 23              23        10000          10000     10000.00000   36 months
# 24              24         6000           6000      6000.00000   36 months
# 25              25        15000          15000     15000.00000   36 months
# 26              26        15000          15000      8725.00000   36 months
# 27              27         5000           5000      5000.00000   60 months
# 28              28         4000           4000      4000.00000   36 months
# 29              29         8500           8500      8500.00000   36 months
# ...            ...          ...            ...             ...         ...
# 887349      887349        20000          20000     20000.00000   36 months
# 887350      887350        10300          10300     10300.00000   60 months
# 887351      887351         4200           4200      4200.00000   36 months
# 887352      887352        15000          15000     15000.00000   36 months
# 887353      887353        15000          15000     15000.00000   60 months
# 887354      887354         6000           6000      6000.00000   36 months
# 887355      887355        26950          26950     26950.00000   36 months
# 887356      887356        23000          23000     23000.00000   60 months
# 887357      887357        18700          18700     18700.00000   60 months
# 887358      887358        25000          25000     25000.00000   60 months
# 887359      887359        25000          25000     25000.00000   60 months
# 887360      887360        26500          26500     26500.00000   60 months
# 887361      887361        21000          21000     21000.00000   36 months
# 887362      887362         8000           8000      8000.00000   36 months
# 887363      887363        12000          12000     12000.00000   36 months
# 887364      887364        10775          10775     10775.00000   36 months
# 887365      887365         7000           7000      7000.00000   36 months
# 887366      887366         6225           6225      6225.00000   36 months
# 887367      887367        10000          10000     10000.00000   36 months
# 887368      887368        13150          13150     13150.00000   60 months
# 887369      887369         4000           4000      4000.00000   36 months
# 887370      887370         7500           7500      7500.00000   36 months
# 887371      887371        10850          10850     10850.00000   36 months
# 887372      887372        12000          12000     12000.00000   36 months
# 887373      887373        11575          11575     11575.00000   36 months
# 887374      887374        10000          10000     10000.00000   36 months
# 887375      887375        24000          24000     24000.00000   36 months
# 887376      887376        13000          13000     13000.00000   60 months
# 887377      887377        12000          12000     12000.00000   60 months
# 887378      887378        20000          20000     20000.00000   36 months
#
#         interest_rate  installment grade sub_grade emp_length  \
# 0               10.65       162.87     B        B2  10+ years
# 1               15.27        59.83     C        C4   < 1 year
# 2               15.96        84.33     C        C5  10+ years
# 3               13.49       339.31     C        C1  10+ years
# 4               12.69        67.79     B        B5     1 year
# 5                7.90       156.46     A        A4    3 years
# 6               15.96       170.08     C        C5    8 years
# 7               18.64       109.43     E        E1    9 years
# 8               21.28       152.39     F        F2    4 years
# 9               12.69       121.45     B        B5   < 1 year
# 10              14.65       153.45     C        C3    5 years
# 11              12.69       402.54     B        B5  10+ years
# 12              13.49       305.38     C        C1   < 1 year
# 13               9.91        96.68     B        B1    3 years
# 14              10.65       325.74     B        B2    3 years
# 15              16.29        35.31     D        D1   < 1 year
# 16              15.27       347.98     C        C4    4 years
# 17               6.03       109.57     A        A1  10+ years
# 18              11.71       198.46     B        B3     1 year
# 19               6.03       280.01     A        A1    6 years
# 20              15.27       484.63     C        C4    3 years
# 21              12.42       701.73     B        B4  10+ years
# 22              11.71       330.76     B        B3  10+ years
# 23              11.71       330.76     B        B3    5 years
# 24              11.71       198.46     B        B3     1 year
# 25               9.91       483.38     B        B1    2 years
# 26              14.27       514.64     C        C2    9 years
# 27              16.77       123.65     D        D2    2 years
# 28              11.71       132.31     B        B3  10+ years
# 29              11.71       281.15     B        B3   < 1 year
# ...               ...          ...   ...       ...        ...
# 887349           6.99       617.46     A        A3    2 years
# 887350          13.66       237.86     C        C3  10+ years
# 887351          15.99       147.64     D        D2  10+ years
# 887352          11.99       498.15     B        B5   < 1 year
# 887353          11.44       329.44     B        B4    4 years
# 887354          17.86       216.50     D        D5  10+ years
# 887355           8.19       846.88     A        A5        NaN
# 887356          15.59       554.32     D        D1  10+ years
# 887357          17.86       473.44     D        D5  10+ years
# 887358          15.99       607.82     D        D2    3 years
# 887359          15.59       602.52     D        D1        NaN
# 887360           8.67       545.87     B        B1  10+ years
# 887361           6.03       639.15     A        A1  10+ years
# 887362           8.19       251.40     A        A5    9 years
# 887363           9.49       384.34     B        B2    4 years
# 887364           6.03       327.95     A        A1   < 1 year
# 887365          14.31       240.30     C        C4  10+ years
# 887366          16.49       220.37     D        D3    2 years
# 887367           6.49       306.45     A        A2     1 year
# 887368          14.99       312.77     C        C5    8 years
# 887369           8.67       126.59     B        B1  10+ years
# 887370           9.49       240.22     B        B2    8 years
# 887371          19.24       399.04     E        E2        NaN
# 887372          11.99       398.52     B        B5   < 1 year
# 887373          15.59       404.61     D        D1  10+ years
# 887374          11.99       332.10     B        B5    8 years
# 887375          11.99       797.03     B        B5  10+ years
# 887376          15.99       316.07     D        D2    5 years
# 887377          19.99       317.86     E        E3     1 year
# 887378          11.99       664.20     B        B5  10+ years
#
#               ...         application_type  acc_now_delinq  year  \
# 0             ...               INDIVIDUAL             0.0  2011
# 1             ...               INDIVIDUAL             0.0  2011
# 2             ...               INDIVIDUAL             0.0  2011
# 3             ...               INDIVIDUAL             0.0  2011
# 4             ...               INDIVIDUAL             0.0  2011
# 5             ...               INDIVIDUAL             0.0  2011
# 6             ...               INDIVIDUAL             0.0  2011
# 7             ...               INDIVIDUAL             0.0  2011
# 8             ...               INDIVIDUAL             0.0  2011
# 9             ...               INDIVIDUAL             0.0  2011
# 10            ...               INDIVIDUAL             0.0  2011
# 11            ...               INDIVIDUAL             0.0  2011
# 12            ...               INDIVIDUAL             0.0  2011
# 13            ...               INDIVIDUAL             0.0  2011
# 14            ...               INDIVIDUAL             0.0  2011
# 15            ...               INDIVIDUAL             0.0  2011
# 16            ...               INDIVIDUAL             0.0  2011
# 17            ...               INDIVIDUAL             0.0  2011
# 18            ...               INDIVIDUAL             0.0  2011
# 19            ...               INDIVIDUAL             0.0  2011
# 20            ...               INDIVIDUAL             0.0  2011
# 21            ...               INDIVIDUAL             0.0  2011
# 22            ...               INDIVIDUAL             0.0  2011
# 23            ...               INDIVIDUAL             0.0  2011
# 24            ...               INDIVIDUAL             0.0  2011
# 25            ...               INDIVIDUAL             0.0  2011
# 26            ...               INDIVIDUAL             0.0  2011
# 27            ...               INDIVIDUAL             0.0  2011
# 28            ...               INDIVIDUAL             0.0  2011
# 29            ...               INDIVIDUAL             0.0  2011
# ...           ...                      ...             ...   ...
# 887349        ...               INDIVIDUAL             0.0  2015
# 887350        ...               INDIVIDUAL             0.0  2015
# 887351        ...               INDIVIDUAL             0.0  2015
# 887352        ...               INDIVIDUAL             0.0  2015
# 887353        ...               INDIVIDUAL             0.0  2015
# 887354        ...               INDIVIDUAL             0.0  2015
# 887355        ...               INDIVIDUAL             0.0  2015
# 887356        ...               INDIVIDUAL             0.0  2015
# 887357        ...               INDIVIDUAL             0.0  2015
# 887358        ...               INDIVIDUAL             0.0  2015
# 887359        ...               INDIVIDUAL             0.0  2015
# 887360        ...               INDIVIDUAL             0.0  2015
# 887361        ...               INDIVIDUAL             0.0  2015
# 887362        ...               INDIVIDUAL             0.0  2015
# 887363        ...               INDIVIDUAL             0.0  2015
# 887364        ...               INDIVIDUAL             0.0  2015
# 887365        ...               INDIVIDUAL             0.0  2015
# 887366        ...               INDIVIDUAL             0.0  2015
# 887367        ...               INDIVIDUAL             0.0  2015
# 887368        ...               INDIVIDUAL             0.0  2015
# 887369        ...               INDIVIDUAL             0.0  2015
# 887370        ...               INDIVIDUAL             0.0  2015
# 887371        ...               INDIVIDUAL             0.0  2015
# 887372        ...               INDIVIDUAL             0.0  2015
# 887373        ...               INDIVIDUAL             0.0  2015
# 887374        ...               INDIVIDUAL             0.0  2015
# 887375        ...               INDIVIDUAL             0.0  2015
# 887376        ...               INDIVIDUAL             0.0  2015
# 887377        ...               INDIVIDUAL             0.0  2015
# 887378        ...               INDIVIDUAL             0.0  2015
#
#        loan_condition        region complete_date emp_length_int  \
# 0           Good Loan       munster    01/12/2011           10.0
# 1            Bad Loan      leinster    01/12/2011            0.5
# 2           Good Loan      cannught    01/12/2011           10.0
# 3           Good Loan        ulster    01/12/2011           10.0
# 4           Good Loan        ulster    01/12/2011            1.0
# 5           Good Loan       munster    01/12/2011            3.0
# 6           Good Loan      leinster    01/12/2011            8.0
# 7           Good Loan        ulster    01/12/2011            9.0
# 8            Bad Loan        ulster    01/12/2011            4.0
# 9            Bad Loan       munster    01/12/2011            0.5
# 10          Good Loan       munster    01/12/2011            5.0
# 11          Good Loan        ulster    01/12/2011           10.0
# 12           Bad Loan      leinster    01/12/2011            0.5
# 13          Good Loan      cannught    01/12/2011            3.0
# 14           Bad Loan        ulster    01/12/2011            3.0
# 15          Good Loan      cannught    01/12/2011            0.5
# 16          Good Loan        ulster    01/12/2011            4.0
# 17          Good Loan  Northern-Irl    01/12/2011           10.0
# 18          Good Loan        ulster    01/12/2011            1.0
# 19          Good Loan        ulster    01/12/2011            6.0
# 20          Good Loan       munster    01/12/2011            3.0
# 21           Bad Loan      leinster    01/12/2011           10.0
# 22          Good Loan       munster    01/12/2011           10.0
# 23          Good Loan        ulster    01/12/2011            5.0
# 24           Bad Loan        ulster    01/12/2011            1.0
# 25          Good Loan      cannught    01/12/2011            2.0
# 26           Bad Loan  Northern-Irl    01/12/2011            9.0
# 27           Bad Loan  Northern-Irl    01/12/2011            2.0
# 28          Good Loan      leinster    01/12/2011           10.0
# 29          Good Loan      cannught    01/12/2011            0.5
# ...               ...           ...           ...            ...
# 887349      Good Loan      leinster    01/01/2015            2.0
# 887350      Good Loan        ulster    01/01/2015           10.0
# 887351       Bad Loan        ulster    01/01/2015           10.0
# 887352      Good Loan  Northern-Irl    01/01/2015            0.5
# 887353      Good Loan      leinster    01/01/2015            4.0
# 887354      Good Loan      leinster    01/01/2015           10.0
# 887355      Good Loan        ulster    01/01/2015            NaN
# 887356      Good Loan        ulster    01/01/2015           10.0
# 887357      Good Loan      leinster    01/01/2015           10.0
# 887358      Good Loan      leinster    01/01/2015            3.0
# 887359      Good Loan      cannught    01/01/2015            NaN
# 887360      Good Loan  Northern-Irl    01/01/2015           10.0
# 887361      Good Loan  Northern-Irl    01/01/2015           10.0
# 887362      Good Loan       munster    01/01/2015            9.0
# 887363      Good Loan        ulster    01/01/2015            4.0
# 887364      Good Loan      leinster    01/01/2015            0.5
# 887365      Good Loan      cannught    01/01/2015           10.0
# 887366      Good Loan      leinster    01/01/2015            2.0
# 887367      Good Loan      leinster    01/01/2015            1.0
# 887368      Good Loan      leinster    01/01/2015            8.0
# 887369      Good Loan        ulster    01/01/2015           10.0
# 887370      Good Loan      cannught    01/01/2015            8.0
# 887371       Bad Loan      cannught    01/01/2015            NaN
# 887372      Good Loan      cannught    01/01/2015            0.5
# 887373      Good Loan       munster    01/01/2015           10.0
# 887374      Good Loan        ulster    01/01/2015            8.0
# 887375      Good Loan  Northern-Irl    01/01/2015           10.0
# 887376      Good Loan      leinster    01/01/2015            5.0
# 887377      Good Loan  Northern-Irl    01/01/2015            1.0
# 887378      Good Loan      leinster    01/01/2015           10.0
#
#        income_category  loan_condition_int  interest_payments
# 0                  Low                   0                Low
# 1                  Low                   1               High
# 2                  Low                   0               High
# 3                  Low                   0               High
# 4                  Low                   0                Low
# 5                  Low                   0                Low
# 6                  Low                   0               High
# 7                  Low                   0               High
# 8                  Low                   1               High
# 9                  Low                   1                Low
# 10                 Low                   0               High
# 11                 Low                   0                Low
# 12                 Low                   1               High
# 13                 Low                   0                Low
# 14                 Low                   1                Low
# 15                 Low                   0               High
# 16                 Low                   0               High
# 17              Medium                   0                Low
# 18                 Low                   0                Low
# 19                 Low                   0                Low
# 20                 Low                   0               High
# 21              Medium                   1                Low
# 22                 Low                   0                Low
# 23                 Low                   0                Low
# 24                 Low                   1                Low
# 25                 Low                   0                Low
# 26                 Low                   1               High
# 27                 Low                   1               High
# 28              Medium                   0                Low
# 29                 Low                   0                Low
# ...                ...                 ...                ...
# 887349             Low                   0                Low
# 887350             Low                   0               High
# 887351             Low                   1               High
# 887352             Low                   0                Low
# 887353             Low                   0                Low
# 887354             Low                   0               High
# 887355             Low                   0                Low
# 887356             Low                   0               High
# 887357             Low                   0               High
# 887358          Medium                   0               High
# 887359             Low                   0               High
# 887360             Low                   0                Low
# 887361             Low                   0                Low
# 887362             Low                   0                Low
# 887363             Low                   0                Low
# 887364             Low                   0                Low
# 887365             Low                   0               High
# 887366             Low                   0               High
# 887367             Low                   0                Low
# 887368             Low                   0               High
# 887369             Low                   0                Low
# 887370             Low                   0                Low
# 887371             Low                   1               High
# 887372             Low                   0                Low
# 887373             Low                   0               High
# 887374             Low                   0                Low
# 887375             Low                   0                Low
# 887376             Low                   0               High
# 887377             Low                   0               High
# 887378             Low                   0                Low
#
# [887379 rows x 56 columns]
# time: 745 ms

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# loan_amount                        0
# funded_amount                      0
# investor_funds                     0
# term                               0
# interest_rate                      0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_length                     44825
# home_ownership                     0
# annual_income                      4
# verification_status                0
# issue_d                            0
# loan_status                        0
# pymnt_plan                         0
# purpose                            0
# addr_state                         0
# dti                                0
# delinq_2yrs                       29
# earliest_cr_line                  29
# inq_last_6mths                    29
# mths_since_last_delinq        454312
# mths_since_last_record        750326
# open_acc                          29
# pub_rec                           29
# revol_bal                          0
# revol_util                       502
# total_acc                         29
# initial_list_status                0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collection_recovery_fee            0
# last_pymnt_d                   17659
# final_d                        17659
# last_pymnt_amnt                    0
# next_pymnt_d                  252971
# last_credit_pull_d                53
# collections_12_mths_ex_med       145
# policy_code                        0
# application_type                   0
# acc_now_delinq                    29
# year                               0
# loan_condition                     0
# region                             0
# complete_date                      0
# emp_length_int                 44825
# income_category                    4
# loan_condition_int                 0
# interest_payments                  0
# dtype: int64
# time: 2.1 s

# %% [markdown]
# # Mapping Home_ownership

# %% [markdown]
#     ## Uniqueness in home_ownership

# %%
ho = df['home_ownership'].unique()
ho
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER', 'NONE', 'ANY'], dtype=object)
# time: 72.8 ms

# %% [markdown]
#     ## mapping

# %%
mapHome = {'RENT':1, 'OWN':2, 'MORTGAGE':3, 'OTHER': 4, 'NONE':5, 'ANY':6}

df['home_ownership_mapped'] = df.home_ownership.map(mapHome)
# Out:
# time: 301 ms

# %%
df[['home_ownership','home_ownership_mapped']]
# Out:
#        home_ownership  home_ownership_mapped
# 0                RENT                      1
# 1                RENT                      1
# 2                RENT                      1
# 3                RENT                      1
# 4                RENT                      1
# 5                RENT                      1
# 6                RENT                      1
# 7                RENT                      1
# 8                 OWN                      2
# 9                RENT                      1
# 10                OWN                      2
# 11                OWN                      2
# 12               RENT                      1
# 13               RENT                      1
# 14               RENT                      1
# 15               RENT                      1
# 16               RENT                      1
# 17           MORTGAGE                      3
# 18           MORTGAGE                      3
# 19               RENT                      1
# 20               RENT                      1
# 21               RENT                      1
# 22                OWN                      2
# 23               RENT                      1
# 24               RENT                      1
# 25           MORTGAGE                      3
# 26               RENT                      1
# 27               RENT                      1
# 28           MORTGAGE                      3
# 29               RENT                      1
# ...               ...                    ...
# 887349       MORTGAGE                      3
# 887350           RENT                      1
# 887351       MORTGAGE                      3
# 887352           RENT                      1
# 887353           RENT                      1
# 887354       MORTGAGE                      3
# 887355           RENT                      1
# 887356       MORTGAGE                      3
# 887357           RENT                      1
# 887358           RENT                      1
# 887359            OWN                      2
# 887360       MORTGAGE                      3
# 887361       MORTGAGE                      3
# 887362       MORTGAGE                      3
# 887363           RENT                      1
# 887364           RENT                      1
# 887365           RENT                      1
# 887366           RENT                      1
# 887367           RENT                      1
# 887368       MORTGAGE                      3
# 887369       MORTGAGE                      3
# 887370           RENT                      1
# 887371            OWN                      2
# 887372       MORTGAGE                      3
# 887373           RENT                      1
# 887374           RENT                      1
# 887375       MORTGAGE                      3
# 887376           RENT                      1
# 887377           RENT                      1
# 887378           RENT                      1
#
# [887379 rows x 2 columns]
# time: 284 ms

# %% [markdown]
# # Mapping emp_length

# %%
df.emp_length.unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)
# time: 161 ms

# %%
mapEmp = {'10+ years':1,'< 1 year':2, '1 year':3, '3 years':4, '8 years':5,
          '9 years':6,'4 years':7,'5 years':8,'6 years':9, '2 years': 10, '7 years':11, 'nan': 12}

df['emp_length_mapped'] = df.emp_length.map(mapEmp)
# Out:
# time: 328 ms

# %%
df[['emp_length', 'emp_length_mapped']]
# Out:
#        emp_length  emp_length_mapped
# 0       10+ years                1.0
# 1        < 1 year                2.0
# 2       10+ years                1.0
# 3       10+ years                1.0
# 4          1 year                3.0
# 5         3 years                4.0
# 6         8 years                5.0
# 7         9 years                6.0
# 8         4 years                7.0
# 9        < 1 year                2.0
# 10        5 years                8.0
# 11      10+ years                1.0
# 12       < 1 year                2.0
# 13        3 years                4.0
# 14        3 years                4.0
# 15       < 1 year                2.0
# 16        4 years                7.0
# 17      10+ years                1.0
# 18         1 year                3.0
# 19        6 years                9.0
# 20        3 years                4.0
# 21      10+ years                1.0
# 22      10+ years                1.0
# 23        5 years                8.0
# 24         1 year                3.0
# 25        2 years               10.0
# 26        9 years                6.0
# 27        2 years               10.0
# 28      10+ years                1.0
# 29       < 1 year                2.0
# ...           ...                ...
# 887349    2 years               10.0
# 887350  10+ years                1.0
# 887351  10+ years                1.0
# 887352   < 1 year                2.0
# 887353    4 years                7.0
# 887354  10+ years                1.0
# 887355        NaN                NaN
# 887356  10+ years                1.0
# 887357  10+ years                1.0
# 887358    3 years                4.0
# 887359        NaN                NaN
# 887360  10+ years                1.0
# 887361  10+ years                1.0
# 887362    9 years                6.0
# 887363    4 years                7.0
# 887364   < 1 year                2.0
# 887365  10+ years                1.0
# 887366    2 years               10.0
# 887367     1 year                3.0
# 887368    8 years                5.0
# 887369  10+ years                1.0
# 887370    8 years                5.0
# 887371        NaN                NaN
# 887372   < 1 year                2.0
# 887373  10+ years                1.0
# 887374    8 years                5.0
# 887375  10+ years                1.0
# 887376    5 years                8.0
# 887377     1 year                3.0
# 887378  10+ years                1.0
#
# [887379 rows x 2 columns]
# time: 497 ms

# %%
df.emp_length_mapped.isnull().sum()
# Out:
# 44825
# time: 35.9 ms

# %%
df['emp_length_mapped'].fillna(value = df['emp_length_mapped'].median(), inplace = True)
# Out:
# time: 142 ms

# %%
df.emp_length_mapped.isnull().sum()
# Out:
# 0
# time: 24.9 ms

# %%
df['emp_length_mapped']=df.emp_length_mapped.astype(int)
# Out:
# time: 164 ms

# %% [markdown]
# # final_d

# %%
# replacing "/"

df['final_d'] = pd.to_numeric(df.final_d.str.replace('/',''))
# Out:
# time: 1.39 s

# %%
df['final_d']
# Out:
# 0         1012015.0
# 1         1042013.0
# 2         1062014.0
# 3         1012015.0
# 4         1012016.0
# 5         1012015.0
# 6         1012016.0
# 7         1012015.0
# 8         1042012.0
# 9         1112012.0
# 10        1062013.0
# 11        1092013.0
# 12        1072012.0
# 13        1012015.0
# 14        1102013.0
# 15        1012015.0
# 16        1012015.0
# 17        1052013.0
# 18        1022015.0
# 19        1072012.0
# 20        1082015.0
# 21        1092013.0
# 22        1012015.0
# 23        1102013.0
# 24        1102012.0
# 25        1092012.0
# 26              NaN
# 27        1122012.0
# 28        1042013.0
# 29        1122014.0
#             ...
# 887349    1012016.0
# 887350    1012016.0
# 887351    1082015.0
# 887352    1012016.0
# 887353    1012016.0
# 887354    1012016.0
# 887355    1012016.0
# 887356    1012016.0
# 887357    1012016.0
# 887358    1012016.0
# 887359    1012016.0
# 887360    1012016.0
# 887361    1012016.0
# 887362    1012016.0
# 887363    1012016.0
# 887364    1072015.0
# 887365    1012016.0
# 887366    1122015.0
# 887367    1012016.0
# 887368    1012016.0
# 887369    1062015.0
# 887370    1012016.0
# 887371    1082015.0
# 887372    1012016.0
# 887373    1012016.0
# 887374    1012016.0
# 887375    1012016.0
# 887376    1012016.0
# 887377    1012016.0
# 887378    1012016.0
# Name: final_d, Length: 887379, dtype: float64
# time: 15 ms

# %%
# Checking null

df.final_d.isnull().sum()
# Out:
# 17659
# time: 163 ms

# %%
# filling null columns of final_d
df['final_d'].fillna(value=df['final_d'].median(), inplace=True)
# Out:
# time: 147 ms

# %%
df.final_d.isnull().sum()
# Out:
# 0
# time: 121 ms

# %%
## converting it into integer
df.final_d.astype(int)
# Out:
# 0         1012015
# 1         1042013
# 2         1062014
# 3         1012015
# 4         1012016
# 5         1012015
# 6         1012016
# 7         1012015
# 8         1042012
# 9         1112012
# 10        1062013
# 11        1092013
# 12        1072012
# 13        1012015
# 14        1102013
# 15        1012015
# 16        1012015
# 17        1052013
# 18        1022015
# 19        1072012
# 20        1082015
# 21        1092013
# 22        1012015
# 23        1102013
# 24        1102012
# 25        1092012
# 26        1012016
# 27        1122012
# 28        1042013
# 29        1122014
#            ...
# 887349    1012016
# 887350    1012016
# 887351    1082015
# 887352    1012016
# 887353    1012016
# 887354    1012016
# 887355    1012016
# 887356    1012016
# 887357    1012016
# 887358    1012016
# 887359    1012016
# 887360    1012016
# 887361    1012016
# 887362    1012016
# 887363    1012016
# 887364    1072015
# 887365    1012016
# 887366    1122015
# 887367    1012016
# 887368    1012016
# 887369    1062015
# 887370    1012016
# 887371    1082015
# 887372    1012016
# 887373    1012016
# 887374    1012016
# 887375    1012016
# 887376    1012016
# 887377    1012016
# 887378    1012016
# Name: final_d, Length: 887379, dtype: int32
# time: 116 ms

# %% [markdown]
# ## Filling empty columns

# %%
# replacing "/"
df['complete_date'] = pd.to_numeric(df.complete_date.str.replace('/',''))
# Out:
# time: 1.44 s

# %%
df.complete_date.isnull().sum()
# Out:
# 0
# time: 25.9 ms

# %%
df['complete_date']
# Out:
# 0         1122011
# 1         1122011
# 2         1122011
# 3         1122011
# 4         1122011
# 5         1122011
# 6         1122011
# 7         1122011
# 8         1122011
# 9         1122011
# 10        1122011
# 11        1122011
# 12        1122011
# 13        1122011
# 14        1122011
# 15        1122011
# 16        1122011
# 17        1122011
# 18        1122011
# 19        1122011
# 20        1122011
# 21        1122011
# 22        1122011
# 23        1122011
# 24        1122011
# 25        1122011
# 26        1122011
# 27        1122011
# 28        1122011
# 29        1122011
#            ...
# 887349    1012015
# 887350    1012015
# 887351    1012015
# 887352    1012015
# 887353    1012015
# 887354    1012015
# 887355    1012015
# 887356    1012015
# 887357    1012015
# 887358    1012015
# 887359    1012015
# 887360    1012015
# 887361    1012015
# 887362    1012015
# 887363    1012015
# 887364    1012015
# 887365    1012015
# 887366    1012015
# 887367    1012015
# 887368    1012015
# 887369    1012015
# 887370    1012015
# 887371    1012015
# 887372    1012015
# 887373    1012015
# 887374    1012015
# 887375    1012015
# 887376    1012015
# 887377    1012015
# 887378    1012015
# Name: complete_date, Length: 887379, dtype: int64
# time: 30.9 ms

# %% [markdown]
# # Mapping region

# %%
df.region.unique()
# Out:
# array(['munster', 'leinster', 'cannught', 'ulster', 'Northern-Irl'],
#       dtype=object)
# time: 185 ms

# %%
## Mapping

mapRegion = {'munster': 1, 'leinster':2,'cannught':3,'ulster':4,'Northern-Irl':5}
df['region_mapped'] = df.region.map(mapRegion)
# Out:
# time: 247 ms

# %%
df[['region','region_mapped']]
# Out:
#               region  region_mapped
# 0            munster              1
# 1           leinster              2
# 2           cannught              3
# 3             ulster              4
# 4             ulster              4
# 5            munster              1
# 6           leinster              2
# 7             ulster              4
# 8             ulster              4
# 9            munster              1
# 10           munster              1
# 11            ulster              4
# 12          leinster              2
# 13          cannught              3
# 14            ulster              4
# 15          cannught              3
# 16            ulster              4
# 17      Northern-Irl              5
# 18            ulster              4
# 19            ulster              4
# 20           munster              1
# 21          leinster              2
# 22           munster              1
# 23            ulster              4
# 24            ulster              4
# 25          cannught              3
# 26      Northern-Irl              5
# 27      Northern-Irl              5
# 28          leinster              2
# 29          cannught              3
# ...              ...            ...
# 887349      leinster              2
# 887350        ulster              4
# 887351        ulster              4
# 887352  Northern-Irl              5
# 887353      leinster              2
# 887354      leinster              2
# 887355        ulster              4
# 887356        ulster              4
# 887357      leinster              2
# 887358      leinster              2
# 887359      cannught              3
# 887360  Northern-Irl              5
# 887361  Northern-Irl              5
# 887362       munster              1
# 887363        ulster              4
# 887364      leinster              2
# 887365      cannught              3
# 887366      leinster              2
# 887367      leinster              2
# 887368      leinster              2
# 887369        ulster              4
# 887370      cannught              3
# 887371      cannught              3
# 887372      cannught              3
# 887373       munster              1
# 887374        ulster              4
# 887375  Northern-Irl              5
# 887376      leinster              2
# 887377  Northern-Irl              5
# 887378      leinster              2
#
# [887379 rows x 2 columns]
# time: 609 ms

# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt
# Out:
# time: 261 ms

# %%
#home_ownership

df['home_ownership_mapped'].hist()
plt.show()
# Out:
# time: 252 ms

# %%
df.groupby('year').loan_amount.agg(['count'])
# Out:
#        count
# year
# 2007     603
# 2008    2393
# 2009    5281
# 2010   12537
# 2011   21721
# 2012   53367
# 2013  134755
# 2014  235628
# 2015  421094
# time: 129 ms

# %%
aa = df.groupby('year').loan_amount.agg(['min','max','mean'])
aa
# Out:
#        min    max          mean
# year
# 2007   500  25000   8254.519071
# 2008   500  25000   8825.428333
# 2009  1000  25000   9833.033516
# 2010  1000  25000  10528.240408
# 2011  1000  35000  12047.503568
# 2012  1000  35000  13461.709015
# 2013  1000  35000  14708.094134
# 2014  1000  35000  14870.177462
# 2015  1000  35000  15240.255561
# time: 84.8 ms

# %%
aa.corr()
# Out:
#            min       max      mean
# min   1.000000  0.597614  0.715935
# max   0.597614  1.000000  0.911836
# mean  0.715935  0.911836  1.000000
# time: 55.9 ms

# %%
aa.plot()
# Out:
# time: 446 ms

# %%
abc = df[['annual_income','loan_amount','funded_amount']]

abc
# Out:
#         annual_income  loan_amount  funded_amount
# 0            24000.00         5000           5000
# 1            30000.00         2500           2500
# 2            12252.00         2400           2400
# 3            49200.00        10000          10000
# 4            80000.00         3000           3000
# 5            36000.00         5000           5000
# 6            47004.00         7000           7000
# 7            48000.00         3000           3000
# 8            40000.00         5600           5600
# 9            15000.00         5375           5375
# 10           72000.00         6500           6500
# 11           75000.00        12000          12000
# 12           30000.00         9000           9000
# 13           15000.00         3000           3000
# 14          100000.00        10000          10000
# 15           28000.00         1000           1000
# 16           42000.00        10000          10000
# 17          110000.00         3600           3600
# 18           84000.00         6000           6000
# 19           77385.19         9200           9200
# 20           43370.00        20250          20250
# 21          105000.00        21000          21000
# 22           50000.00        10000          10000
# 23           50000.00        10000          10000
# 24           76000.00         6000           6000
# 25           92000.00        15000          15000
# 26           60000.00        15000          15000
# 27           50004.00         5000           5000
# 28          106000.00         4000           4000
# 29           25000.00         8500           8500
# ...               ...          ...            ...
# 887349       72000.00        20000          20000
# 887350       93600.00        10300          10300
# 887351       48000.00         4200           4200
# 887352       70000.00        15000          15000
# 887353       57000.00        15000          15000
# 887354       90000.00         6000           6000
# 887355       54000.00        26950          26950
# 887356       50000.00        23000          23000
# 887357       52000.00        18700          18700
# 887358      103000.00        25000          25000
# 887359       55000.00        25000          25000
# 887360       92000.00        26500          26500
# 887361       65000.00        21000          21000
# 887362       50000.00         8000           8000
# 887363       40000.00        12000          12000
# 887364       54000.00        10775          10775
# 887365       57000.00         7000           7000
# 887366       27000.00         6225           6225
# 887367       75000.00        10000          10000
# 887368       30000.00        13150          13150
# 887369       50000.00         4000           4000
# 887370       40000.00         7500           7500
# 887371       32000.00        10850          10850
# 887372       63000.00        12000          12000
# 887373       25400.00        11575          11575
# 887374       31000.00        10000          10000
# 887375       79000.00        24000          24000
# 887376       35000.00        13000          13000
# 887377       64400.00        12000          12000
# 887378      100000.00        20000          20000
#
# [887379 rows x 3 columns]
# time: 53.9 ms

# %%
am = abc.head(100)
# Out:
# time: 81.8 ms

# %%
am.plot(kind='line')
# Out:
# time: 385 ms

# %%
am.plot(kind='box')
# Out:
# time: 250 ms

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# loan_amount                        0
# funded_amount                      0
# investor_funds                     0
# term                               0
# interest_rate                      0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_length                     44825
# home_ownership                     0
# annual_income                      4
# verification_status                0
# issue_d                            0
# loan_status                        0
# pymnt_plan                         0
# purpose                            0
# addr_state                         0
# dti                                0
# delinq_2yrs                       29
# earliest_cr_line                  29
# inq_last_6mths                    29
# mths_since_last_delinq        454312
# mths_since_last_record        750326
# open_acc                          29
# pub_rec                           29
# revol_bal                          0
# revol_util                       502
# total_acc                         29
# initial_list_status                0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collection_recovery_fee            0
# last_pymnt_d                   17659
# final_d                            0
# last_pymnt_amnt                    0
# next_pymnt_d                  252971
# last_credit_pull_d                53
# collections_12_mths_ex_med       145
# policy_code                        0
# application_type                   0
# acc_now_delinq                    29
# year                               0
# loan_condition                     0
# region                             0
# complete_date                      0
# emp_length_int                 44825
# income_category                    4
# loan_condition_int                 0
# interest_payments                  0
# home_ownership_mapped              0
# emp_length_mapped                  0
# region_mapped                      0
# dtype: int64
# time: 2.11 s

# %%
# Out:
# 0          1
# 1          2
# 2          1
# 3          1
# 4          3
# 5          4
# 6          5
# 7          6
# 8          7
# 9          2
# 10         8
# 11         1
# 12         2
# 13         4
# 14         4
# 15         2
# 16         7
# 17         1
# 18         3
# 19         9
# 20         4
# 21         1
# 22         1
# 23         8
# 24         3
# 25        10
# 26         6
# 27        10
# 28         1
# 29         2
#           ..
# 887349    10
# 887350     1
# 887351     1
# 887352     2
# 887353     7
# 887354     1
# 887355     4
# 887356     1
# 887357     1
# 887358     4
# 887359     4
# 887360     1
# 887361     1
# 887362     6
# 887363     7
# 887364     2
# 887365     1
# 887366    10
# 887367     3
# 887368     5
# 887369     1
# 887370     5
# 887371     4
# 887372     2
# 887373     1
# 887374     5
# 887375     1
# 887376     8
# 887377     3
# 887378     1
# Name: emp_length_mapped, Length: 887379, dtype: int32
# time: 11 ms

# %% [markdown]
# # filling annual_income

# %%
df['annual_income'].fillna(value=df['annual_income'].median(), inplace= True)
# Out:
# time: 48.9 ms

# %%
df['annual_income'].isnull().sum()
# Out:
# 0
# time: 22.9 ms

# %%
df['annual_income'].astype(int)
# Out:
# 0          24000
# 1          30000
# 2          12252
# 3          49200
# 4          80000
# 5          36000
# 6          47004
# 7          48000
# 8          40000
# 9          15000
# 10         72000
# 11         75000
# 12         30000
# 13         15000
# 14        100000
# 15         28000
# 16         42000
# 17        110000
# 18         84000
# 19         77385
# 20         43370
# 21        105000
# 22         50000
# 23         50000
# 24         76000
# 25         92000
# 26         60000
# 27         50004
# 28        106000
# 29         25000
#            ...
# 887349     72000
# 887350     93600
# 887351     48000
# 887352     70000
# 887353     57000
# 887354     90000
# 887355     54000
# 887356     50000
# 887357     52000
# 887358    103000
# 887359     55000
# 887360     92000
# 887361     65000
# 887362     50000
# 887363     40000
# 887364     54000
# 887365     57000
# 887366     27000
# 887367     75000
# 887368     30000
# 887369     50000
# 887370     40000
# 887371     32000
# 887372     63000
# 887373     25400
# 887374     31000
# 887375     79000
# 887376     35000
# 887377     64400
# 887378    100000
# Name: annual_income, Length: 887379, dtype: int32
# time: 18.9 ms

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# loan_amount                        0
# funded_amount                      0
# investor_funds                     0
# term                               0
# interest_rate                      0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_length                     44825
# home_ownership                     0
# annual_income                      0
# verification_status                0
# issue_d                            0
# loan_status                        0
# pymnt_plan                         0
# purpose                            0
# addr_state                         0
# dti                                0
# delinq_2yrs                       29
# earliest_cr_line                  29
# inq_last_6mths                    29
# mths_since_last_delinq        454312
# mths_since_last_record        750326
# open_acc                          29
# pub_rec                           29
# revol_bal                          0
# revol_util                       502
# total_acc                         29
# initial_list_status                0
# out_prncp                          0
# out_prncp_inv                      0
# total_pymnt                        0
# total_pymnt_inv                    0
# total_rec_prncp                    0
# total_rec_int                      0
# total_rec_late_fee                 0
# recoveries                         0
# collection_recovery_fee            0
# last_pymnt_d                   17659
# final_d                            0
# last_pymnt_amnt                    0
# next_pymnt_d                  252971
# last_credit_pull_d                53
# collections_12_mths_ex_med       145
# policy_code                        0
# application_type                   0
# acc_now_delinq                    29
# year                               0
# loan_condition                     0
# region                             0
# complete_date                      0
# emp_length_int                 44825
# income_category                    4
# loan_condition_int                 0
# interest_payments                  0
# home_ownership_mapped              0
# emp_length_mapped                  0
# region_mapped                      0
# dtype: int64
# time: 2.07 s

# %% [markdown]
# # mths_since_last_delinq

# %%
df.mths_since_last_delinq
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3         35.0
# 4         38.0
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16        61.0
# 17         NaN
# 18         8.0
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27        20.0
# 28        18.0
# 29         NaN
#           ...
# 887349    69.0
# 887350    17.0
# 887351    38.0
# 887352     NaN
# 887353     NaN
# 887354     NaN
# 887355     NaN
# 887356     NaN
# 887357    30.0
# 887358     NaN
# 887359     NaN
# 887360    17.0
# 887361     NaN
# 887362    24.0
# 887363     8.0
# 887364    16.0
# 887365    10.0
# 887366     NaN
# 887367    29.0
# 887368     NaN
# 887369     NaN
# 887370    69.0
# 887371    65.0
# 887372     9.0
# 887373     NaN
# 887374     NaN
# 887375    26.0
# 887376     NaN
# 887377    22.0
# 887378     NaN
# Name: mths_since_last_delinq, Length: 887379, dtype: float64
# time: 12 ms

# %%
p = df.mths_since_last_delinq.hist()
# Out:
# time: 331 ms

# %% [markdown]
# # income_category

# %%
df.income_category.unique()
# Out:
# array(['Low', 'Medium', 'High', nan], dtype=object)
# time: 152 ms

# %%
mapIncome = {'Low':1, 'Medium':2, 'High':3, 'nan':'nan'}
df['income_category_mapped'] = df.income_category.map(mapIncome)
# Out:
# time: 144 ms

# %%
df['income_category_mapped'].fillna(value=df['income_category_mapped'].median(), inplace=True)
# Out:
# time: 592 ms

# %%
df[['income_category','income_category_mapped']]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-77-6d0daeddfff4> in <module>
# ----> 1 df[['income_category','income_category_mapped']]
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2725         else:
#    2726             indexer = self.loc._convert_to_indexer(key, axis=1)
# -> 2727             return self._take(indexer, axis=1)
#    2728
#    2729     def _getitem_multilevel(self, key):
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    2783     @Appender(_shared_docs['_take'])
#    2784     def _take(self, indices, axis=0, is_copy=True):
# -> 2785         self._consolidate_inplace()
#    2786
#    2787         new_data = self._data.take(indices,
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    4437             self._data = self._data.consolidate()
#    4438
# -> 4439         self._protect_consolidate(f)
#    4440
#    4441     def _consolidate(self, inplace=False):
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    4426         """
#    4427         blocks_before = len(self._data.blocks)
# -> 4428         result = f()
#    4429         if len(self._data.blocks) != blocks_before:
#    4430             self._clear_item_cache()
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in f()
#    4435
#    4436         def f():
# -> 4437             self._data = self._data.consolidate()
#    4438
#    4439         self._protect_consolidate(f)
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in consolidate(self)
#    4096         bm = self.__class__(self.blocks, self.axes)
#    4097         bm._is_consolidated = False
# -> 4098         bm._consolidate_inplace()
#    4099         return bm
#    4100
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _consolidate_inplace(self)
#    4101     def _consolidate_inplace(self):
#    4102         if not self.is_consolidated():
# -> 4103             self.blocks = tuple(_consolidate(self.blocks))
#    4104             self._is_consolidated = True
#    4105             self._known_consolidated = True
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _consolidate(blocks)
#    5067     for (_can_consolidate, dtype), group_blocks in grouper:
#    5068         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 5069                                       _can_consolidate=_can_consolidate)
#    5070         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    5071     return new_blocks
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    5087         # combination of those slices is a slice, too.
#    5088         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 5089         new_values = _vstack([b.values for b in blocks], dtype)
#    5090
#    5091         argsort = np.argsort(new_mgr_locs)
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _vstack(to_stack, dtype)
#    5133
#    5134     else:
# -> 5135         return np.vstack(to_stack)
#    5136
#    5137
#
# c:\users\saijal shakya\appdata\local\programs\python\python36-32\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# MemoryError:
# time: 30.9 ms
