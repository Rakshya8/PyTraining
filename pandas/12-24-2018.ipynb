# %%
import pandas as pd

# %%
import numpy as np

# %%
# %load_ext autotime

# %%
df = pd.read_csv("loan_test.csv")
# Out:
# time: 27.8 s

# %%
df
# Out:
#         Unnamed: 0  loan_amount  funded_amount  investor_funds        term  \
# 0                0         5000           5000      4975.00000   36 months
# 1                1         2500           2500      2500.00000   60 months
# 2                2         2400           2400      2400.00000   36 months
# 3                3        10000          10000     10000.00000   36 months
# 4                4         3000           3000      3000.00000   60 months
# 5                5         5000           5000      5000.00000   36 months
# 6                6         7000           7000      7000.00000   60 months
# 7                7         3000           3000      3000.00000   36 months
# 8                8         5600           5600      5600.00000   60 months
# 9                9         5375           5375      5350.00000   60 months
# 10              10         6500           6500      6500.00000   60 months
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# loan_amount                        0
# funded_amount                      0
# investor_funds                     0
# term                               0
# interest_rate                      0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_length                     44825
# home_ownership                     0
# annual_income                      4
# verification_status                0
# issue_d                            0
# loan_status                        0
# pymnt_plan                         0
# purpose                            0
# addr_state                         0
# dti                                0
# delinq_2yrs                       29
# earliest_cr_line                  29
# inq_last_6mths                    29
# mths_since_last_delinq        454312
# mths_since_last_record        750326
# open_acc                          29
# ...

# %%
df.home_ownership
# Out:
# 0             RENT
# 1             RENT
# 2             RENT
# 3             RENT
# 4             RENT
# 5             RENT
# 6             RENT
# 7             RENT
# 8              OWN
# 9             RENT
# 10             OWN
# 11             OWN
# 12            RENT
# 13            RENT
# 14            RENT
# 15            RENT
# 16            RENT
# 17        MORTGAGE
# 18        MORTGAGE
# 19            RENT
# 20            RENT
# 21            RENT
# 22             OWN
# 23            RENT
# 24            RENT
# 25        MORTGAGE
# 26            RENT
# 27            RENT
# 28        MORTGAGE
# 29            RENT
#             ...
# 887349    MORTGAGE
# 887350        RENT
# 887351    MORTGAGE
# 887352        RENT
# 887353        RENT
# 887354    MORTGAGE
# 887355        RENT
# 887356    MORTGAGE
# 887357        RENT
# 887358        RENT
# 887359         OWN
# 887360    MORTGAGE
# 887361    MORTGAGE
# 887362    MORTGAGE
# 887363        RENT
# 887364        RENT
# ...

# %%
df.home_ownership .unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER', 'NONE', 'ANY'], dtype=object)
# time: 332 ms

# %%
a = df['home_ownership']
# Out:
# time: 180 ms

# %%
a
# Out:
# 0             RENT
# 1             RENT
# 2             RENT
# 3             RENT
# 4             RENT
# 5             RENT
# 6             RENT
# 7             RENT
# 8              OWN
# 9             RENT
# 10             OWN
# 11             OWN
# 12            RENT
# 13            RENT
# 14            RENT
# 15            RENT
# 16            RENT
# 17        MORTGAGE
# 18        MORTGAGE
# 19            RENT
# 20            RENT
# 21            RENT
# 22             OWN
# 23            RENT
# 24            RENT
# 25        MORTGAGE
# 26            RENT
# 27            RENT
# 28        MORTGAGE
# 29            RENT
#             ...
# 887349    MORTGAGE
# 887350        RENT
# 887351    MORTGAGE
# 887352        RENT
# 887353        RENT
# 887354    MORTGAGE
# 887355        RENT
# 887356    MORTGAGE
# 887357        RENT
# 887358        RENT
# 887359         OWN
# 887360    MORTGAGE
# 887361    MORTGAGE
# 887362    MORTGAGE
# 887363        RENT
# 887364        RENT
# ...

# %%
dictionarys = {'RENT':1,'OWN':2,'MORTGAGE':3,'OTHER':4,'NONE':5,'ANY':6}
# Out:
# time: 85.8 ms

# %%
df['home_ownership_cat'] = df.home_ownership.map(dictionarys)
# Out:
# time: 281 ms

# %%
df[['home_ownership','home_ownership_cat']]
# Out:
#        home_ownership  home_ownership_cat
# 0                RENT                   1
# 1                RENT                   1
# 2                RENT                   1
# 3                RENT                   1
# 4                RENT                   1
# 5                RENT                   1
# 6                RENT                   1
# 7                RENT                   1
# 8                 OWN                   2
# 9                RENT                   1
# 10                OWN                   2
# 11                OWN                   2
# 12               RENT                   1
# 13               RENT                   1
# 14               RENT                   1
# 15               RENT                   1
# 16               RENT                   1
# 17           MORTGAGE                   3
# 18           MORTGAGE                   3
# 19               RENT                   1
# 20               RENT                   1
# ...

# %%
df['emp_length']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3efc8f16cd42> in <module>
# ----> 1 type(df['emp_length'])
#
# NameError: name 'df' is not defined

# %%
df['complete_date'] = pd.to_numeric(df.complete_date.str.replace('/',''))
# Out:
# time: 1.65 s

# %%
df.complete_date.astype(int)
# Out:
# 0         1122011
# 1         1122011
# 2         1122011
# 3         1122011
# 4         1122011
# 5         1122011
# 6         1122011
# 7         1122011
# 8         1122011
# 9         1122011
# 10        1122011
# 11        1122011
# 12        1122011
# 13        1122011
# 14        1122011
# 15        1122011
# 16        1122011
# 17        1122011
# 18        1122011
# 19        1122011
# 20        1122011
# 21        1122011
# 22        1122011
# 23        1122011
# 24        1122011
# 25        1122011
# 26        1122011
# 27        1122011
# 28        1122011
# 29        1122011
#            ...
# 887349    1012015
# 887350    1012015
# 887351    1012015
# 887352    1012015
# 887353    1012015
# 887354    1012015
# 887355    1012015
# 887356    1012015
# 887357    1012015
# 887358    1012015
# 887359    1012015
# 887360    1012015
# 887361    1012015
# 887362    1012015
# 887363    1012015
# 887364    1012015
# 887365    1012015
# 887366    1012015
# 887367    1012015
# ...

# %%
df['emp_length'].unique() 

#categorize 1 2 3 4.....
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)
# time: 309 ms

# %%
df['home_ownership'].value_counts()
# Out:
# MORTGAGE    443557
# RENT        356117
# OWN          87470
# OTHER          182
# NONE            50
# ANY              3
# Name: home_ownership, dtype: int64
# time: 222 ms

# %%
import matplotlib.pyplot as plt
df['home_ownership_cat'].hist()
plt.show()
# Out:
# time: 450 ms

# %%
import matplotlib as plt
df['home_ownership_cat'].plot()
# Out:
# time: 757 ms

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'loan_amount', 'funded_amount', 'investor_funds', 'term',
#        'interest_rate', 'installment', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'annual_income', 'verification_status', 'issue_d',
#        'loan_status', 'pymnt_plan', 'purpose', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'final_d', 'last_pymnt_amnt', 'next_pymnt_d',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'year', 'loan_condition',
# ...

# %%
df
# Out:
#         Unnamed: 0  loan_amount  funded_amount  investor_funds        term  \
# 0                0         5000           5000      4975.00000   36 months
# 1                1         2500           2500      2500.00000   60 months
# 2                2         2400           2400      2400.00000   36 months
# 3                3        10000          10000     10000.00000   36 months
# 4                4         3000           3000      3000.00000   60 months
# 5                5         5000           5000      5000.00000   36 months
# 6                6         7000           7000      7000.00000   60 months
# 7                7         3000           3000      3000.00000   36 months
# 8                8         5600           5600      5600.00000   60 months
# 9                9         5375           5375      5350.00000   60 months
# 10              10         6500           6500      6500.00000   60 months
# ...

# %%
df.groupby('year').loan_amount.agg(['count'])
# Out:
#        count
# year
# 2007     603
# 2008    2393
# 2009    5281
# 2010   12537
# 2011   21721
# 2012   53367
# 2013  134755
# 2014  235628
# 2015  421094
# time: 208 ms

# %%
df.groupby('year').loan_amount.agg(['count']).min()
# Out:
# count    603
# dtype: int64
# time: 54.8 ms

# %%
aa = df.groupby('year').loan_amount.agg(['min','max','mean'])
#aa = df.groupby('year').loan_amount.agg(['count','min','max','mean'])
aa
# Out:
#        min    max          mean
# year
# 2007   500  25000   8254.519071
# 2008   500  25000   8825.428333
# 2009  1000  25000   9833.033516
# 2010  1000  25000  10528.240408
# 2011  1000  35000  12047.503568
# 2012  1000  35000  13461.709015
# 2013  1000  35000  14708.094134
# 2014  1000  35000  14870.177462
# 2015  1000  35000  15240.255561
# time: 215 ms

# %%
aa.plot()
# Out:
# time: 315 ms

# %%
aa.plot?
# Out:
# time: 46.9 ms

# %%
aa.plot(None,None,kind='bar', title='Loan Stat')
# Out:
# time: 452 ms

# %%
aa.plot(kind='box')
# Out:
# time: 225 ms

# %%
aa.corr()
# Out:
#            min       max      mean
# min   1.000000  0.597614  0.715935
# max   0.597614  1.000000  0.911836
# mean  0.715935  0.911836  1.000000
# time: 12 ms

# %%
abc = df[['annual_income','loan_amount','funded_amount']]

abc
# Out:
#         annual_income  loan_amount  funded_amount
# 0            24000.00         5000           5000
# 1            30000.00         2500           2500
# 2            12252.00         2400           2400
# 3            49200.00        10000          10000
# 4            80000.00         3000           3000
# 5            36000.00         5000           5000
# 6            47004.00         7000           7000
# 7            48000.00         3000           3000
# 8            40000.00         5600           5600
# 9            15000.00         5375           5375
# 10           72000.00         6500           6500
# 11           75000.00        12000          12000
# 12           30000.00         9000           9000
# 13           15000.00         3000           3000
# 14          100000.00        10000          10000
# 15           28000.00         1000           1000
# 16           42000.00        10000          10000
# 17          110000.00         3600           3600
# ...

# %%
abc.plot(kind='bar')

# %%
pd.to_numeric?

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
