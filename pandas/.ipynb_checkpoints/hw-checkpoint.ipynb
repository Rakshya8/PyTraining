# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('loan_test.csv')
df
# Out:
#         Unnamed: 0  loan_amount  funded_amount  investor_funds        term  \
# 0                0         5000           5000      4975.00000   36 months
# 1                1         2500           2500      2500.00000   60 months
# 2                2         2400           2400      2400.00000   36 months
# 3                3        10000          10000     10000.00000   36 months
# 4                4         3000           3000      3000.00000   60 months
# 5                5         5000           5000      5000.00000   36 months
# 6                6         7000           7000      7000.00000   60 months
# 7                7         3000           3000      3000.00000   36 months
# 8                8         5600           5600      5600.00000   60 months
# 9                9         5375           5375      5350.00000   60 months
# 10              10         6500           6500      6500.00000   60 months
# ...

# %%
a = {'10+ years':1,'< 1 year':2, '1 year':3, '3 years':4, '8 years':5,
          '9 years':6,'4 years':7,'5 years':8,'6 years':9, '2 years': 10, '7 years':11, 'nan': 12}

df['emp_length_cat'] = df.emp_length.map(a)

# %%
df[['emp_length', 'emp_length_cat']]
# Out:
#        emp_length  emp_length_cat
# 0       10+ years             1.0
# 1        < 1 year             2.0
# 2       10+ years             1.0
# 3       10+ years             1.0
# 4          1 year             3.0
# 5         3 years             4.0
# 6         8 years             5.0
# 7         9 years             6.0
# 8         4 years             7.0
# 9        < 1 year             2.0
# 10        5 years             8.0
# 11      10+ years             1.0
# 12       < 1 year             2.0
# 13        3 years             4.0
# 14        3 years             4.0
# 15       < 1 year             2.0
# 16        4 years             7.0
# 17      10+ years             1.0
# 18         1 year             3.0
# 19        6 years             9.0
# 20        3 years             4.0
# 21      10+ years             1.0
# 22      10+ years             1.0
# 23        5 years             8.0
# 24         1 year             3.0
# 25        2 years            10.0
# ...

# %%
df['emp_length_cat'].fillna(value = df['emp_length_cat'].median(), inplace = True)

# %%
df.emp_length_cat
# Out:
# 0          1.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          3.0
# 5          4.0
# 6          5.0
# 7          6.0
# 8          7.0
# 9          2.0
# 10         8.0
# 11         1.0
# 12         2.0
# 13         4.0
# 14         4.0
# 15         2.0
# 16         7.0
# 17         1.0
# 18         3.0
# 19         9.0
# 20         4.0
# 21         1.0
# 22         1.0
# 23         8.0
# 24         3.0
# 25        10.0
# 26         6.0
# 27        10.0
# 28         1.0
# 29         2.0
#           ...
# 887349    10.0
# 887350     1.0
# 887351     1.0
# 887352     2.0
# 887353     7.0
# 887354     1.0
# 887355     4.0
# 887356     1.0
# 887357     1.0
# 887358     4.0
# 887359     4.0
# 887360     1.0
# 887361     1.0
# 887362     6.0
# 887363     7.0
# 887364     2.0
# 887365     1.0
# 887366    10.0
# 887367     3.0
# 887368     5.0
# 887369     1.0
# 887370     5.0
# 887371     4.0
# 887372     2.0
# 887373     1.0
# 887374     5.0
# 887375     1.0
# ...
