# %%
# %load_ext autotime

# %%
py1 = list(range(100000))
py2 = list(range(100000))
# Out:
# time: 8.95 ms

# %%
import numpy as np

np_a = np.arange(100000)
np_ab = np.arange(100000)
# Out:
# time: 989 µs
